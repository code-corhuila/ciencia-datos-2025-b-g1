# %% [markdown]
# # 📘 Proyecto de Ciencia de Datos
# ## Análisis de la Relación entre Actividades y Parciales
#
# ---
#
# ### 👩‍🎓 Estudiante: *Julieth Shirley Cruz Posada*
# ### 📚 Asignatura: Ciencia de Datos
# ### 🏫 Institución: *Corporación Universitaria del Huila*
# ### 📅 Fecha: 3 de octubre 2025
#
# ---

# %%
# ==============================================
# 📊 GENERACIÓN DE DATOS: CONSUMO ENERGÉTICO SEMANAL
# ==============================================
# Este script crea datos simulados para análisis temporal.
# Se guardan automáticamente en Google Drive:
# /Mi unidad/Ciencia-datos-2025-b-g1/FORO 1
# ==============================================

# ✅ 1. Conectar con Google Drive
from google.colab import drive
drive.mount('/content/drive')

# ✅ 2. Crear carpeta destino si no existe
import os
ruta_base = "/content/drive/MyDrive/Ciencia-datos-2025-b-g1/FORO 1"
os.makedirs(ruta_base, exist_ok=True)

# ✅ 3. Importar librerías
import pandas as pd
import numpy as np

# ✅ 4. Generar datos simulados de consumo energético semanal
np.random.seed(42)
fechas = pd.date_range(start="2023-01-01", periods=104, freq="W")  # 2 años de datos
# consumo base con patrón estacional
consumo = 500 + 30 * np.sin(np.linspace(0, 3*np.pi, 104)) + np.random.normal(0, 10, 104)

# Crear DataFrame
df = pd.DataFrame({
    'fecha': fechas,
    'consumo_MWh': consumo
})

# ✅ 5. Guardar los datos en CSV dentro de tu carpeta
ruta_datos = os.path.join(ruta_base, "consumo_energetico.csv")
df.to_csv(ruta_datos, index=False)

print(f"✅ Archivo guardado correctamente en:\n{ruta_datos}")

# ✅ 6. Vista previa de los datos
df.head()
# Out:
# Mounted at /content/drive
# ✅ Archivo guardado correctamente en:
# /content/drive/MyDrive/Ciencia-datos-2025-b-g1/FORO 1/consumo_energetico.csv
#        fecha  consumo_MWh
# 0 2023-01-01   504.967142
# 1 2023-01-08   501.358609
# 2 2023-01-15   511.936453
# 3 2023-01-22   523.362503
# 4 2023-01-29   508.395266
