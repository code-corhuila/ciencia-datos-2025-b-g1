# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgeandreschauxplazas/ciencia-datos-2025-b-g1/blob/main/Solucion_parcial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EJERCICIO PARCIAL            JORGE ANDRES CHAUX- JUAN ESTEBAN CORTES
#
# PARTE II
#
# Caso: Obtener a partir de una data base el porcentaje de perdida en un
# salon

# %%
# Out:
# The total number of students is: 15

# %%
# Out:
#        Estudiante  Nota1 (20%)  Nota2 (20%)  Nota3 (20%)  Nota4 (40%)  \
# 0    Estudiante_1          2.5          2.0          2.3          2.1
# 1    Estudiante_2          2.8          2.5          2.9          2.7
# 2    Estudiante_3          4.0          4.2          4.5          4.8
# 3    Estudiante_4          2.2          2.4          2.0          2.3
# 4    Estudiante_5          1.9          2.5          2.0          2.3
# 5    Estudiante_6          4.5          4.7          4.8          4.9
# 6    Estudiante_7          3.8          3.6          3.9          4.0
# 7    Estudiante_8          2.7          2.3          2.5          2.4
# 8    Estudiante_9          2.0          2.1          2.4          2.5
# 9   Estudiante_10          2.4          2.2          2.1          2.2
# 10  Estudiante_11          3.1          3.0          3.2          3.3
# 11  Estudiante_12          2.3          2.0          2.4          2.6
# ...

# %%
# Out:
# The total number of students is: 15

# %%
# Out:
#        Estudiante  Nota_Definitiva
# 0    Estudiante_1             2.20
# 1    Estudiante_2             2.72
# 2    Estudiante_3             4.46
# 3    Estudiante_4             2.24
# 4    Estudiante_5             2.20
# 5    Estudiante_6             4.78
# 6    Estudiante_7             3.88
# 7    Estudiante_8             2.46
# 8    Estudiante_9             2.36
# 9   Estudiante_10             2.22
# 10  Estudiante_11             3.16
# 11  Estudiante_12             2.44
# 12  Estudiante_13             2.32
# 13  Estudiante_14             4.18
# 14  Estudiante_15             2.34

# %%
# Out:
# The number of students with a final grade below 3.0 is: 10

# %%
# Out:
# The percentage of failing students is: 66.67%

# %%
import matplotlib.pyplot as plt

# Assuming 'failing_students_count' and 'total_students' are already defined from previous steps
passing_students_count = total_students - failing_students_count

labels = ['Failing Students (< 3.0)', 'Passing Students (>= 3.0)']
sizes = [failing_students_count, passing_students_count]
colors = ['#ff9999','#66b3ff']
explode = (0.1, 0)  # explode the 1st slice (i.e. 'Failing Students')

plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Students by Final Grade')
plt.show()
